# %% [markdown]
# # First we load in the data

# %%
import numpy as np    
import scipy.io as sp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation


#Setting up with fluid flow data
fluid_data = sp.loadmat('cylALL.mat')

velocity_data = fluid_data['UALL']
n = int(fluid_data['n'][0][0])
m = int(fluid_data['m'][0][0])

velocity_data_reshaped = np.reshape(velocity_data, (n, m, 151), order='C').T

# %%
fig,ax = plt.subplots()
ax.imshow(velocity_data_reshaped[150,:,:],cmap='jet')

# %% [markdown]
# # Initialize all the SHRED stuff

# %%
from pyshred import DataManager, SHRED, SHREDEngine, DeviceConfig

manager = DataManager(
    lags = 12,
    train_size= 0.8,
    val_size = 0.1,
    test_size = 0.1    
)

manager.add_data(
    data = velocity_data_reshaped,
    id = 'u_velocity',
    random = 3,
    compress = False
)

train_dataset, val_dataset, test_dataset= manager.prepare()
DeviceConfig(device_type = 'cuda') # Set up device to use GPU

shred = SHRED(
    sequence_model="LSTM",
    decoder_model="MLP",
    latent_forecaster="LSTM_Forecaster"
)

# %% [markdown]
# # Training

# %%
val_errors = shred.fit(
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    num_epochs=140,
    batch_size= 32,
    verbose = True,
    lr = 0.0004,
    patience = 100
)
# Out:
# Fitting SHRED...
# Epoch 1: Average training loss = 0.345885
# Validation MSE (epoch 1): 0.333856
# Epoch 2: Average training loss = 0.322222
# Validation MSE (epoch 2): 0.299209
# Epoch 3: Average training loss = 0.279805
# Validation MSE (epoch 3): 0.243433
# Epoch 4: Average training loss = 0.217552
# Validation MSE (epoch 4): 0.171706
# Epoch 5: Average training loss = 0.149379
# Validation MSE (epoch 5): 0.124712
# Epoch 6: Average training loss = 0.132875
# Validation MSE (epoch 6): 0.138865
# Epoch 7: Average training loss = 0.132431
# Validation MSE (epoch 7): 0.119609
# Epoch 8: Average training loss = 0.115789
# Validation MSE (epoch 8): 0.115786
# Epoch 9: Average training loss = 0.116207
# Validation MSE (epoch 9): 0.120010
# Epoch 10: Average training loss = 0.118696
# Validation MSE (epoch 10): 0.119302
# Epoch 11: Average training loss = 0.116707
# Validation MSE (epoch 11): 0.116727
# Epoch 12: Average training loss = 0.115062
# Validation MSE (epoch 12): 0.116345
# Epoch 13: Average training loss = 0.115141
# Validation MSE (epoch 13): 0.115962
# Epoch 14: Average training loss = 0.114555
# Validation MSE (epoch 14): 0.114865
# Epoch 15: Average training loss = 0.113832
# Validation MSE (epoch 15): 0.114595
# Epoch 16: Average training loss = 0.113865
# Validation MSE (epoch 16): 0.114803
# Epoch 17: Average training loss = 0.114040
# Validation MSE (epoch 17): 0.114593
# Epoch 18: Average training loss = 0.113791
# Validation MSE (epoch 18): 0.114503
# Epoch 19: Average training loss = 0.113667
# Validation MSE (epoch 19): 0.114616
# Epoch 20: Average training loss = 0.113650
# Validation MSE (epoch 20): 0.114542
# Epoch 21: Average training loss = 0.113595
# Validation MSE (epoch 21): 0.114545
# Epoch 22: Average training loss = 0.113500
# Validation MSE (epoch 22): 0.114608
# Epoch 23: Average training loss = 0.113634
# Validation MSE (epoch 23): 0.114651
# Epoch 24: Average training loss = 0.113540
# Validation MSE (epoch 24): 0.114581
# Epoch 25: Average training loss = 0.113490
# Validation MSE (epoch 25): 0.114498
# Epoch 26: Average training loss = 0.113643
# Validation MSE (epoch 26): 0.114462
# Epoch 27: Average training loss = 0.113549
# Validation MSE (epoch 27): 0.114474
# Epoch 28: Average training loss = 0.113392
# Validation MSE (epoch 28): 0.114325
# Epoch 29: Average training loss = 0.113487
# Validation MSE (epoch 29): 0.114250
# Epoch 30: Average training loss = 0.113351
# Validation MSE (epoch 30): 0.114223
# Epoch 31: Average training loss = 0.113293
# Validation MSE (epoch 31): 0.114296
# Epoch 32: Average training loss = 0.113348
# Validation MSE (epoch 32): 0.114516
# Epoch 33: Average training loss = 0.113376
# Validation MSE (epoch 33): 0.114657
# Epoch 34: Average training loss = 0.113152
# Validation MSE (epoch 34): 0.114549
# Epoch 35: Average training loss = 0.113017
# Validation MSE (epoch 35): 0.114192
# Epoch 36: Average training loss = 0.112912
# Validation MSE (epoch 36): 0.113849
# Epoch 37: Average training loss = 0.112832
# Validation MSE (epoch 37): 0.113469
# Epoch 38: Average training loss = 0.112703
# Validation MSE (epoch 38): 0.113085
# Epoch 39: Average training loss = 0.112415
# Validation MSE (epoch 39): 0.112762
# Epoch 40: Average training loss = 0.111907
# Validation MSE (epoch 40): 0.112490
# Epoch 41: Average training loss = 0.111046
# Validation MSE (epoch 41): 0.111657
# Epoch 42: Average training loss = 0.110112
# Validation MSE (epoch 42): 0.109712
# Epoch 43: Average training loss = 0.108449
# Validation MSE (epoch 43): 0.106626
# Epoch 44: Average training loss = 0.105548
# Validation MSE (epoch 44): 0.101641
# Epoch 45: Average training loss = 0.100445
# Validation MSE (epoch 45): 0.094097
# Epoch 46: Average training loss = 0.092949
# Validation MSE (epoch 46): 0.085514
# Epoch 47: Average training loss = 0.084051
# Validation MSE (epoch 47): 0.079744
# Epoch 48: Average training loss = 0.074626
# Validation MSE (epoch 48): 0.076458
# Epoch 49: Average training loss = 0.068830
# Validation MSE (epoch 49): 0.071527
# Epoch 50: Average training loss = 0.061477
# Validation MSE (epoch 50): 0.060697
# Epoch 51: Average training loss = 0.047939
# Validation MSE (epoch 51): 0.043466
# Epoch 52: Average training loss = 0.031189
# Validation MSE (epoch 52): 0.025657
# Epoch 53: Average training loss = 0.024145
# Validation MSE (epoch 53): 0.020594
# Epoch 54: Average training loss = 0.021991
# Validation MSE (epoch 54): 0.018557
# Epoch 55: Average training loss = 0.019644
# Validation MSE (epoch 55): 0.014062
# Epoch 56: Average training loss = 0.016608
# Validation MSE (epoch 56): 0.012159
# Epoch 57: Average training loss = 0.014560
# Validation MSE (epoch 57): 0.011253
# Epoch 58: Average training loss = 0.015386
# Validation MSE (epoch 58): 0.010955
# Epoch 59: Average training loss = 0.013575
# Validation MSE (epoch 59): 0.009946
# Epoch 60: Average training loss = 0.012481
# Validation MSE (epoch 60): 0.009296
# Epoch 61: Average training loss = 0.011490
# Validation MSE (epoch 61): 0.009044
# Epoch 62: Average training loss = 0.011501
# Validation MSE (epoch 62): 0.007668
# Epoch 63: Average training loss = 0.010415
# Validation MSE (epoch 63): 0.007009
# Epoch 64: Average training loss = 0.009807
# Validation MSE (epoch 64): 0.006350
# Epoch 65: Average training loss = 0.009165
# Validation MSE (epoch 65): 0.005559
# Epoch 66: Average training loss = 0.008067
# Validation MSE (epoch 66): 0.004875
# Epoch 67: Average training loss = 0.007985
# Validation MSE (epoch 67): 0.004185
# Epoch 68: Average training loss = 0.006883
# Validation MSE (epoch 68): 0.003427
# Epoch 69: Average training loss = 0.006233
# Validation MSE (epoch 69): 0.003120
# Epoch 70: Average training loss = 0.005496
# Validation MSE (epoch 70): 0.002460
# Epoch 71: Average training loss = 0.004895
# Validation MSE (epoch 71): 0.002244
# Epoch 72: Average training loss = 0.004904
# Validation MSE (epoch 72): 0.002089
# Epoch 73: Average training loss = 0.005210
# Validation MSE (epoch 73): 0.001563
# Epoch 74: Average training loss = 0.004728
# Validation MSE (epoch 74): 0.001409
# Epoch 75: Average training loss = 0.004791
# Validation MSE (epoch 75): 0.001343
# Epoch 76: Average training loss = 0.004412
# Validation MSE (epoch 76): 0.001236
# Epoch 77: Average training loss = 0.004680
# Validation MSE (epoch 77): 0.001167
# Epoch 78: Average training loss = 0.004407
# Validation MSE (epoch 78): 0.001254
# Epoch 79: Average training loss = 0.004215
# Validation MSE (epoch 79): 0.001104
# Epoch 80: Average training loss = 0.004420
# Validation MSE (epoch 80): 0.001087
# Epoch 81: Average training loss = 0.004257
# Validation MSE (epoch 81): 0.001156
# Epoch 82: Average training loss = 0.004254
# Validation MSE (epoch 82): 0.000997
# Epoch 83: Average training loss = 0.004007
# Validation MSE (epoch 83): 0.001306
# Epoch 84: Average training loss = 0.004157
# Validation MSE (epoch 84): 0.000927
# Epoch 85: Average training loss = 0.004247
# Validation MSE (epoch 85): 0.000959
# Epoch 86: Average training loss = 0.003744
# Validation MSE (epoch 86): 0.000937
# Epoch 87: Average training loss = 0.003787
# Validation MSE (epoch 87): 0.000871
# Epoch 88: Average training loss = 0.003845
# Validation MSE (epoch 88): 0.000880
# Epoch 89: Average training loss = 0.003778
# Validation MSE (epoch 89): 0.000835
# Epoch 90: Average training loss = 0.003874
# Validation MSE (epoch 90): 0.000803
# Epoch 91: Average training loss = 0.003552
# Validation MSE (epoch 91): 0.000861
# Epoch 92: Average training loss = 0.003539
# Validation MSE (epoch 92): 0.000759
# Epoch 93: Average training loss = 0.003418
# Validation MSE (epoch 93): 0.000816
# Epoch 94: Average training loss = 0.003783
# Validation MSE (epoch 94): 0.000841
# Epoch 95: Average training loss = 0.003482
# Validation MSE (epoch 95): 0.000703
# Epoch 96: Average training loss = 0.003271
# Validation MSE (epoch 96): 0.000717
# Epoch 97: Average training loss = 0.003648
# Validation MSE (epoch 97): 0.000660
# Epoch 98: Average training loss = 0.003392
# Validation MSE (epoch 98): 0.000617
# Epoch 99: Average training loss = 0.003276
# Validation MSE (epoch 99): 0.000799
# Epoch 100: Average training loss = 0.003337
# Validation MSE (epoch 100): 0.000617
# Epoch 101: Average training loss = 0.003318
# Validation MSE (epoch 101): 0.000572
# Epoch 102: Average training loss = 0.003256
# Validation MSE (epoch 102): 0.000667
# Epoch 103: Average training loss = 0.003185
# Validation MSE (epoch 103): 0.000573
# Epoch 104: Average training loss = 0.003327
# Validation MSE (epoch 104): 0.000604
# Epoch 105: Average training loss = 0.002930
# Validation MSE (epoch 105): 0.000834
# Epoch 106: Average training loss = 0.003562
# Validation MSE (epoch 106): 0.000571
# Epoch 107: Average training loss = 0.003133
# Validation MSE (epoch 107): 0.000516
# Epoch 108: Average training loss = 0.003000
# Validation MSE (epoch 108): 0.000591
# Epoch 109: Average training loss = 0.003133
# Validation MSE (epoch 109): 0.000534
# Epoch 110: Average training loss = 0.003155
# Validation MSE (epoch 110): 0.000592
# Epoch 111: Average training loss = 0.002947
# Validation MSE (epoch 111): 0.000644
# Epoch 112: Average training loss = 0.002895
# Validation MSE (epoch 112): 0.000508
# Epoch 113: Average training loss = 0.003154
# Validation MSE (epoch 113): 0.000498
# Epoch 114: Average training loss = 0.002799
# Validation MSE (epoch 114): 0.000735
# Epoch 115: Average training loss = 0.002983
# Validation MSE (epoch 115): 0.000492
# Epoch 116: Average training loss = 0.003010
# Validation MSE (epoch 116): 0.000542
# Epoch 117: Average training loss = 0.002742
# Validation MSE (epoch 117): 0.000504
# Epoch 118: Average training loss = 0.003097
# Validation MSE (epoch 118): 0.000532
# Epoch 119: Average training loss = 0.002617
# Validation MSE (epoch 119): 0.000528
# Epoch 120: Average training loss = 0.002902
# Validation MSE (epoch 120): 0.000443
# Epoch 121: Average training loss = 0.003028
# Validation MSE (epoch 121): 0.000556
# Epoch 122: Average training loss = 0.002775
# Validation MSE (epoch 122): 0.000667
# Epoch 123: Average training loss = 0.003041
# Validation MSE (epoch 123): 0.000472
# Epoch 124: Average training loss = 0.003039
# Validation MSE (epoch 124): 0.000479
# Epoch 125: Average training loss = 0.002498
# Validation MSE (epoch 125): 0.000664
# Epoch 126: Average training loss = 0.002789
# Validation MSE (epoch 126): 0.000564
# Epoch 127: Average training loss = 0.002775
# Validation MSE (epoch 127): 0.000431
# Epoch 128: Average training loss = 0.002655
# Validation MSE (epoch 128): 0.000500
# Epoch 129: Average training loss = 0.002755
# Validation MSE (epoch 129): 0.000577
# Epoch 130: Average training loss = 0.002915
# Validation MSE (epoch 130): 0.000483
# Epoch 131: Average training loss = 0.002833
# Validation MSE (epoch 131): 0.000465
# Epoch 132: Average training loss = 0.002778
# Validation MSE (epoch 132): 0.000534
# Epoch 133: Average training loss = 0.002906
# Validation MSE (epoch 133): 0.000491
# Epoch 134: Average training loss = 0.002640
# Validation MSE (epoch 134): 0.000411
# Epoch 135: Average training loss = 0.002460
# Validation MSE (epoch 135): 0.000433
# Epoch 136: Average training loss = 0.002703
# Validation MSE (epoch 136): 0.000399
# Epoch 137: Average training loss = 0.002505
# Validation MSE (epoch 137): 0.000387
# Epoch 138: Average training loss = 0.002385
# Validation MSE (epoch 138): 0.000357
# Epoch 139: Average training loss = 0.002675
# Validation MSE (epoch 139): 0.000580
# Epoch 140: Average training loss = 0.002650
# Validation MSE (epoch 140): 0.000418

# %% [markdown]
# # Downstream tasks

# %%
engine = SHREDEngine(manager, shred) #Initialize the SHRED engine used for downstream tasks

# obtain latent space of test sensor measurements
test_latent_from_sensors = engine.sensor_to_latent(manager.test_sensor_measurements)

# generate latent states from validation sensor measurements
val_latents = engine.sensor_to_latent(manager.val_sensor_measurements)

# decode latent space generated from sensor measurements (generated using engine.sensor_to_latent())
test_reconstruction = engine.decode(test_latent_from_sensors)

# ---------------- Train Evaluation ----------------
t_train = len(manager.train_sensor_measurements)
train_Y = {'u_velocity': velocity_data_reshaped[0:t_train]}  # Ground truth segment
train_error = engine.evaluate(manager.train_sensor_measurements, train_Y)

# ---------------- Validation Evaluation ----------------
t_val = len(manager.val_sensor_measurements)
val_Y = {'u_velocity': velocity_data_reshaped[t_train:t_train + t_val]}
val_error = engine.evaluate(manager.val_sensor_measurements, val_Y)

# ---------------- Test Evaluation ----------------
t_test = len(manager.test_sensor_measurements)
test_Y = {'u_velocity': velocity_data_reshaped[-t_test:]}
test_error = engine.evaluate(manager.test_sensor_measurements, test_Y)

# ---------------- Print Results ----------------
print("---------- TRAIN ----------")
print(train_error)

print("\n---------- VALIDATION ----------")
print(val_error)

print("\n---------- TEST ----------")
print(test_error)
# Out:
# ---------- TRAIN ----------
#                  MSE      RMSE       MAE      R2
# dataset
# u_velocity  0.000091  0.009556  0.006111  0.9948
#
# ---------- VALIDATION ----------
#                  MSE      RMSE       MAE        R2
# dataset
# u_velocity  0.000302  0.017389  0.009375  0.958349
#
# ---------- TEST ----------
#                  MSE      RMSE       MAE        R2
# dataset
# u_velocity  0.020939  0.144702  0.081658 -0.922124

# %%
h = len(manager.test_sensor_measurements) # Prediction horizon

sensor_loc = manager.sensor_summary_df['loc/traj'].values
# print(f"Sensor locations (x,y): {sensor_loc}")

# The first reconstructions are not good because the meassurements are padded with zeros. So when you are far enough into the "future" to match your lags 
# you can start evaluating the reconstructions
h = len(manager.test_sensor_measurements)  # Prediction horizon
index = (-1)  # Index of the final frame in the test set (considering lags) 
# Final ground truth frame from the test set
truth = velocity_data_reshaped[index]

# Extract final reconstructed frame (from sensor-based latents)
reconstructions = test_reconstruction["u_velocity"]
reconstruction = reconstructions[index]


# Create side-by-side comparison plot
fig,ax = plt.subplots(1,2, figsize=(20,5))
cf0 = ax[0].contourf(reconstruction, levels=100, cmap='jet')
ax[0].set_title('SHRED Reconstruction')
fig.colorbar(cf0, ax=ax[0])
cf1 = ax[1].contourf(abs(truth - reconstruction), levels=100, cmap='jet')
ax[1].set_title('Absolute Difference')
fig.colorbar(cf1, ax=ax[1])  # Add colorbar to the second plot
for y,x in sensor_loc:
    ax[0].plot(x,y,markersize=5,color='white',marker='o')
    ax[1].plot(x,y,markersize=5,color='white',marker='o')
# ax.plot(x,forecast,label = 'forecast')
# ax.legend()

# %%
dff = (abs(truth - reconstruction)+1)/(truth+1)-1
np.max(dff)
# Out:
# 0.3037627047729512

# %%
manager.sensor_summary_df['loc/traj'].values
# Out:
# array([(3, 247), (65, 185), (77, 78)], dtype=object)

# %%
print(manager.test_sensor_measurements[0:1,:])
engine.sensor_to_latent(manager.test_sensor_measurements[0:1,:]).shape
# test_reconstruction = engine.decode(test_latent_from_sensors[0,:])
# Out:
# [[0.873896 0.818198 1.21796 ]]
# (1, 64)
